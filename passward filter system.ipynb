# %%
symbol = "^(?=.*[0-9])(?=.*[a-z])(?=.*[A-Z])(?=.*[!@#$%^&*()_+\\-=\\[\\]{};':\"\\\\|,.<>/?]).{8,20}$"
user_name= input("Enter your Name or EmailId: ")
passward=input("passward: ")
if  passward == symbol and passward>8:
    print("WELCOME TO PLATFORM")
else:
    print("EXIT")
# Out:
# Enter your Name or EmailId:  kin
# passward:  kin*aftV
# EXIT

# %%
import re
user_name= input("Enter your Name or EmailId: ")
password=input("passward: ")
if len(password) < 8 or len(password) > 20:
    print("! Password must be between 8 and 20 characters.")
elif not re.search(r"[0-9]", password):
    print(" ! Must contain at least one digit.")
elif not re.search(r"[a-z]", password):
    print("! Must contain at least one lowercase letter.")
elif not re.search(r"[A-Z]", password):
    print("! Must contain at least one uppercase letter.")
elif not re.search(r"[!@#$%^&*()_+\-=\[\]{};':\"\\|,.<>/?]", password):
    print("! Must contain at least one special character.")
else:
    print("✅ Password is valid. WELCOME TO PLATFORM")
# Out:
# Enter your Name or EmailId:  asfr4323
# passward:  assf431345
# ❌ Must contain at least one uppercase letter.
